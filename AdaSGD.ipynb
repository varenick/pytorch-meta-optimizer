# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms

# %%
from time import time

# %%
USE_CUDA = torch.cuda.is_available()
USE_CUDA
# Out:
# True

# %%
def cuda_wrapper(torch_obj):
    if USE_CUDA:
        return torch_obj.cuda()
    else:
        return torch_obj

# %%
class ModelFullyConnected(nn.Module):

    def __init__(self, num_hidden=1, hidden_size=32, dropout_rate=0.5):
        super(ModelFullyConnected, self).__init__()
        assert num_hidden > 0
        self.input_size = (28, 28)
        self.output_size = 10
        self.num_hidden = num_hidden
        self.dropout_rate = dropout_rate
        self.input_layer = nn.Linear(self.input_size[0] * self.input_size[1], hidden_size)
        self.hidden_layers = nn.ModuleList()
        for _ in range(num_hidden):
            self.hidden_layers.append(nn.Linear(hidden_size, hidden_size))
        self.output_layer = nn.Linear(hidden_size, self.output_size)

    def forward(self, inputs):
        x = inputs.view(-1, self.input_size[0] * self.input_size[1])
        x = F.dropout(F.relu(self.input_layer(x)), p=self.dropout_rate)
        for layer in self.hidden_layers:
            x = F.dropout(F.relu(layer(x)), p=self.dropout_rate)
        x = self.output_layer(x)
        return F.log_softmax(x, dim=1)

# %%
class ModelConvolutional(nn.Module):

    def __init__(self, num_hidden=1, fc_hidden_size=32, dropout_rate=0.5, num_filters=16, filter_size=3):
        super(ModelConvolutional, self).__init__()
        assert num_hidden > 0
        self.input_size = (28, 28)
        self.output_size = 10
        self.num_hidden = num_hidden
        self.num_filters = num_filters
        self.dropout_rate = dropout_rate
        self.input_layer = nn.Conv2d(1, num_filters, filter_size)
        self.hidden_layers = nn.ModuleList()
        for _ in range(num_hidden):
            self.hidden_layers.append(nn.Conv2d(num_filters, num_filters, filter_size))
        self.size_after_convs = (
            self.input_size[0] - (filter_size - 1) * (num_hidden + 1), 
            self.input_size[1] - (filter_size - 1) * (num_hidden + 1)
        )
        self.fc_layer = nn.Linear(self.size_after_convs[0] * self.size_after_convs[1] * num_filters, fc_hidden_size)
        self.output_layer = nn.Linear(fc_hidden_size, self.output_size)

    def forward(self, inputs):
        x = inputs.view(-1, 1, self.input_size[0], self.input_size[1])
        x = F.relu(self.input_layer(x))
        for layer in self.hidden_layers:
            x = F.relu(layer(x))
        x = x.view(-1, self.size_after_convs[0] * self.size_after_convs[1] * self.num_filters)
        #print(x.size())
        x = F.dropout(F.relu(self.fc_layer(x)), p=self.dropout_rate)
        #print(x.size())
        x = self.output_layer(x)
        #print(x.size())
        return F.log_softmax(x, dim=1)

# %%
class SGD_with_adaptive_lr():
    
    def __init__(self, params, init_base_lr=1e-3, meta_lr=1e-3, meta_betas=(0.9, 0.999), meta_eps=1e-8):
        self.params = list(params)
        self.base_lr = nn.Parameter(torch.Tensor([init_base_lr]))
        self.base_lr.grad = torch.zeros_like(self.base_lr)
        self.meta_opt = optim.Adam([self.base_lr], lr=meta_lr, betas=meta_betas, eps=meta_eps)
        self.flat_grads = 0
        
    def step(self):
        grads = []
        for param in self.params:
            grads.append(param.grad.data.view(-1))
        self.flat_grads += torch.cat(grads)
        for param in self.params:
            param.data = param.data - self.base_lr.data[0] * param.grad.data 

    def meta_step(self):
        grads = []
        for param in self.params:
            grads.append(param.grad.data.view(-1))
        flat_grads_new = torch.cat(grads)
        self.meta_opt.zero_grad()
        self.base_lr.grad.data = torch.clamp(
            torch.Tensor([-torch.sum(self.flat_grads * flat_grads_new)]), -1, 1
        )
        self.meta_opt.step()
        self.flat_grads = 0

# %%
batch_size = 32
test_batch_size = 32
max_epoch = 20
do_validation = False

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if USE_CUDA else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=test_batch_size, shuffle=True, **kwargs)

# %%
losses = {}
test_losses = {}
times = {}
learning_rates = {}

# %%
Model = ModelFullyConnected
model_kwargs = {
    'num_hidden': 2, 
    'hidden_size': 256, 
    'dropout_rate': 0.8
}
model_name = '_'.join(['fc'] + [key + '=' + str(val) for key, val in model_kwargs.items()])
print(model_name)
# Out:
# fc_num_hidden=2_hidden_size=256_dropout_rate=0.8

# %%
losses[model_name] = {}
test_losses[model_name] = {}
times[model_name] = {}
learning_rates[model_name] = {}

# %%
torch.manual_seed(123)

#meta_opt_names = []

run_count = 3

meta_lr = 1e-4

for truncated_bptt_step in [1, 10, 100]:
    opt_name = 'AdaSGD' + '_bptt_steps=' + str(truncated_bptt_step) + '_meta_lr=' + str(meta_lr)
    print(opt_name)
    meta_opt_names.append(opt_name)
    
    losses[model_name][opt_name] = []
    test_losses[model_name][opt_name] = []
    times[model_name][opt_name] = []
    learning_rates[model_name][opt_name] = []
    
    for run in range(run_count):
        losses[model_name][opt_name].append([])
        test_losses[model_name][opt_name].append([])
        times[model_name][opt_name].append([])
        learning_rates[model_name][opt_name].append([])
        
        model = cuda_wrapper(Model(**model_kwargs))
        opt = SGD_with_adaptive_lr(model.parameters(), init_base_lr=1e-2, meta_lr=meta_lr)

        av_loss = 0
        av_test_loss = 0
        alpha = 0.999
        global_step = 0

        start_time = time()

        for epoch in range(max_epoch):
            epoch_start_time = time()
            for X, y in train_loader:
                X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                prob = model(X)
                loss = F.nll_loss(prob, y)
                model.zero_grad()
                do_meta_step = ((global_step + 1) % truncated_bptt_step == 0)
                if do_meta_step:
                    loss.backward(retain_graph=True)
                else:
                    loss.backward()
                opt.step()
                
                av_loss = alpha * av_loss + (1 - alpha) * loss.data[0]
                losses[model_name][opt_name][run].append(loss.data[0])
                
                if do_meta_step:
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                    model.zero_grad()
                    loss.backward()
                    opt.meta_step()
                    
                learning_rates[model_name][opt_name][run].append(opt.base_lr.data[0])
                times[model_name][opt_name][run].append(time() - start_time)
                
                global_step += 1
                
            if do_validation:
                for X, y in test_loader:
                    X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                
                    av_test_loss = alpha * av_test_loss + (1 - alpha) * loss.data[0]
                    test_losses[model_name][opt_name][run].append(test_loss.data[0])

            print('epoch {} took {:.1f}s; av_loss = {:.3f}; av_test_loss = {:.3f}; lr = {:.4f}'.format(
                epoch+1, time() - epoch_start_time, av_loss, av_test_loss, opt.base_lr.data[0]
            ))
        
        print()
        
    losses[model_name][opt_name] = np.array(losses[model_name][opt_name])
    test_losses[model_name][opt_name] = np.array(test_losses[model_name][opt_name])
    times[model_name][opt_name] = np.array(times[model_name][opt_name])
    learning_rates[model_name][opt_name] = np.array(learning_rates[model_name][opt_name])
# Out:
# AdaSGD_bptt_steps=1_meta_lr=0.0001
# epoch 1 took 8.5s; av_loss = 0.242; av_test_loss = 0.000; lr = 0.1034
# epoch 2 took 8.2s; av_loss = 0.131; av_test_loss = 0.000; lr = 0.1219
# epoch 3 took 8.8s; av_loss = 0.084; av_test_loss = 0.000; lr = 0.1256
# epoch 4 took 9.5s; av_loss = 0.060; av_test_loss = 0.000; lr = 0.1318
# epoch 5 took 8.5s; av_loss = 0.047; av_test_loss = 0.000; lr = 0.1299
# epoch 6 took 8.8s; av_loss = 0.034; av_test_loss = 0.000; lr = 0.1302
# epoch 7 took 8.5s; av_loss = 0.030; av_test_loss = 0.000; lr = 0.1264
# epoch 8 took 8.2s; av_loss = 0.022; av_test_loss = 0.000; lr = 0.1256
# epoch 9 took 8.7s; av_loss = 0.018; av_test_loss = 0.000; lr = 0.1243
# epoch 10 took 9.0s; av_loss = 0.015; av_test_loss = 0.000; lr = 0.1157
# epoch 11 took 8.7s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.1165
# epoch 12 took 8.8s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.1090
# epoch 13 took 9.1s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.1066
# epoch 14 took 9.2s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1083
# epoch 15 took 9.2s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.1093
# epoch 16 took 9.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1123
# epoch 17 took 8.1s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1135
# epoch 18 took 8.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1184
# epoch 19 took 10.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1208
# epoch 20 took 9.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1190
#
# epoch 1 took 9.5s; av_loss = 0.243; av_test_loss = 0.000; lr = 0.1018
# epoch 2 took 8.4s; av_loss = 0.130; av_test_loss = 0.000; lr = 0.1213
# epoch 3 took 8.6s; av_loss = 0.086; av_test_loss = 0.000; lr = 0.1298
# epoch 4 took 8.6s; av_loss = 0.062; av_test_loss = 0.000; lr = 0.1340
# epoch 5 took 9.3s; av_loss = 0.047; av_test_loss = 0.000; lr = 0.1308
# epoch 6 took 8.9s; av_loss = 0.034; av_test_loss = 0.000; lr = 0.1316
# epoch 7 took 8.7s; av_loss = 0.030; av_test_loss = 0.000; lr = 0.1367
# epoch 8 took 9.3s; av_loss = 0.023; av_test_loss = 0.000; lr = 0.1297
# epoch 9 took 8.5s; av_loss = 0.015; av_test_loss = 0.000; lr = 0.1211
# epoch 10 took 9.1s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.1166
# epoch 11 took 8.8s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.1168
# epoch 12 took 9.4s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.1146
# epoch 13 took 8.7s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.1068
# epoch 14 took 8.5s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.1009
# epoch 15 took 9.2s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.1003
# epoch 16 took 9.4s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1044
# epoch 17 took 8.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1096
# epoch 18 took 9.2s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1168
# epoch 19 took 8.5s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1258
# epoch 20 took 8.9s; av_loss = 0.011; av_test_loss = 0.000; lr = 0.1300
#
# epoch 1 took 8.1s; av_loss = 0.239; av_test_loss = 0.000; lr = 0.0999
# epoch 2 took 8.5s; av_loss = 0.128; av_test_loss = 0.000; lr = 0.1187
# epoch 3 took 9.0s; av_loss = 0.082; av_test_loss = 0.000; lr = 0.1263
# epoch 4 took 9.0s; av_loss = 0.062; av_test_loss = 0.000; lr = 0.1304
# epoch 5 took 9.2s; av_loss = 0.047; av_test_loss = 0.000; lr = 0.1305
# epoch 6 took 8.4s; av_loss = 0.037; av_test_loss = 0.000; lr = 0.1287
# epoch 7 took 8.7s; av_loss = 0.028; av_test_loss = 0.000; lr = 0.1258
# epoch 8 took 8.4s; av_loss = 0.020; av_test_loss = 0.000; lr = 0.1217
# epoch 9 took 8.9s; av_loss = 0.014; av_test_loss = 0.000; lr = 0.1169
# epoch 10 took 8.4s; av_loss = 0.014; av_test_loss = 0.000; lr = 0.1161
# epoch 11 took 8.4s; av_loss = 0.009; av_test_loss = 0.000; lr = 0.1144
# epoch 12 took 8.2s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.1110
# epoch 13 took 9.0s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1096
# epoch 14 took 11.4s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.1165
# epoch 15 took 9.5s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.1122
# epoch 16 took 9.8s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.1094
# epoch 17 took 8.5s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1032
# epoch 18 took 8.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1088
# epoch 19 took 9.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1130
# epoch 20 took 9.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1182
#
# AdaSGD_bptt_steps=10_meta_lr=0.0001
# epoch 1 took 7.9s; av_loss = 0.365; av_test_loss = 0.000; lr = 0.0280
# epoch 2 took 7.5s; av_loss = 0.183; av_test_loss = 0.000; lr = 0.0408
# epoch 3 took 7.6s; av_loss = 0.110; av_test_loss = 0.000; lr = 0.0463
# epoch 4 took 8.0s; av_loss = 0.076; av_test_loss = 0.000; lr = 0.0498
# epoch 5 took 7.9s; av_loss = 0.055; av_test_loss = 0.000; lr = 0.0505
# epoch 6 took 7.8s; av_loss = 0.040; av_test_loss = 0.000; lr = 0.0517
# epoch 7 took 7.8s; av_loss = 0.034; av_test_loss = 0.000; lr = 0.0514
# epoch 8 took 7.5s; av_loss = 0.025; av_test_loss = 0.000; lr = 0.0509
# epoch 9 took 8.1s; av_loss = 0.019; av_test_loss = 0.000; lr = 0.0512
# epoch 10 took 8.0s; av_loss = 0.014; av_test_loss = 0.000; lr = 0.0514
# epoch 11 took 7.7s; av_loss = 0.011; av_test_loss = 0.000; lr = 0.0510
# epoch 12 took 7.5s; av_loss = 0.009; av_test_loss = 0.000; lr = 0.0507
# epoch 13 took 7.5s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.0504
# epoch 14 took 7.9s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0503
# epoch 15 took 7.5s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0503
# epoch 16 took 7.5s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0504
# epoch 17 took 7.9s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0505
# epoch 18 took 7.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0506
# epoch 19 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0506
# epoch 20 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0507
#
# epoch 1 took 8.0s; av_loss = 0.370; av_test_loss = 0.000; lr = 0.0275
# epoch 2 took 7.6s; av_loss = 0.184; av_test_loss = 0.000; lr = 0.0391
# epoch 3 took 7.8s; av_loss = 0.110; av_test_loss = 0.000; lr = 0.0438
# epoch 4 took 8.2s; av_loss = 0.075; av_test_loss = 0.000; lr = 0.0462
# epoch 5 took 7.6s; av_loss = 0.054; av_test_loss = 0.000; lr = 0.0463
# epoch 6 took 7.5s; av_loss = 0.043; av_test_loss = 0.000; lr = 0.0462
# epoch 7 took 8.6s; av_loss = 0.032; av_test_loss = 0.000; lr = 0.0460
# epoch 8 took 7.7s; av_loss = 0.024; av_test_loss = 0.000; lr = 0.0459
# epoch 9 took 7.8s; av_loss = 0.019; av_test_loss = 0.000; lr = 0.0459
# epoch 10 took 7.8s; av_loss = 0.013; av_test_loss = 0.000; lr = 0.0461
# epoch 11 took 8.3s; av_loss = 0.011; av_test_loss = 0.000; lr = 0.0461
# epoch 12 took 7.7s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0460
# epoch 13 took 7.7s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.0463
# epoch 14 took 8.1s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0465
# epoch 15 took 7.9s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0468
# epoch 16 took 7.6s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0464
# epoch 17 took 8.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0466
# epoch 18 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0467
# epoch 19 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0468
# epoch 20 took 7.9s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0469
#
# epoch 1 took 7.4s; av_loss = 0.370; av_test_loss = 0.000; lr = 0.0281
# epoch 2 took 8.0s; av_loss = 0.186; av_test_loss = 0.000; lr = 0.0404
# epoch 3 took 7.9s; av_loss = 0.112; av_test_loss = 0.000; lr = 0.0472
# epoch 4 took 7.8s; av_loss = 0.077; av_test_loss = 0.000; lr = 0.0493
# epoch 5 took 7.7s; av_loss = 0.058; av_test_loss = 0.000; lr = 0.0512
# epoch 6 took 7.9s; av_loss = 0.042; av_test_loss = 0.000; lr = 0.0520
# epoch 7 took 8.4s; av_loss = 0.033; av_test_loss = 0.000; lr = 0.0525
# epoch 8 took 7.9s; av_loss = 0.026; av_test_loss = 0.000; lr = 0.0531
# epoch 9 took 7.9s; av_loss = 0.020; av_test_loss = 0.000; lr = 0.0529
# epoch 10 took 8.3s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.0528
# epoch 11 took 8.2s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.0529
# epoch 12 took 8.1s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0527
# epoch 13 took 7.7s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.0524
# epoch 14 took 7.4s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0527
# epoch 15 took 7.9s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0522
# epoch 16 took 7.6s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0524
# epoch 17 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0525
# epoch 18 took 7.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0526
# epoch 19 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0527
# epoch 20 took 7.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0528
#
# AdaSGD_bptt_steps=100_meta_lr=0.0001
# epoch 1 took 7.7s; av_loss = 0.420; av_test_loss = 0.000; lr = 0.0118
# epoch 2 took 7.4s; av_loss = 0.248; av_test_loss = 0.000; lr = 0.0135
# epoch 3 took 7.4s; av_loss = 0.165; av_test_loss = 0.000; lr = 0.0152
# epoch 4 took 7.6s; av_loss = 0.119; av_test_loss = 0.000; lr = 0.0163
# epoch 5 took 7.5s; av_loss = 0.090; av_test_loss = 0.000; lr = 0.0171
# epoch 6 took 7.7s; av_loss = 0.071; av_test_loss = 0.000; lr = 0.0177
# epoch 7 took 7.6s; av_loss = 0.056; av_test_loss = 0.000; lr = 0.0180
# epoch 8 took 8.2s; av_loss = 0.046; av_test_loss = 0.000; lr = 0.0184
# epoch 9 took 7.8s; av_loss = 0.039; av_test_loss = 0.000; lr = 0.0187
# epoch 10 took 7.5s; av_loss = 0.032; av_test_loss = 0.000; lr = 0.0190
# epoch 11 took 7.3s; av_loss = 0.024; av_test_loss = 0.000; lr = 0.0192
# epoch 12 took 7.8s; av_loss = 0.020; av_test_loss = 0.000; lr = 0.0193
# epoch 13 took 7.7s; av_loss = 0.016; av_test_loss = 0.000; lr = 0.0195
# epoch 14 took 7.4s; av_loss = 0.011; av_test_loss = 0.000; lr = 0.0196
# epoch 15 took 7.8s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.0197
# epoch 16 took 7.7s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0198
# epoch 17 took 7.3s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.0198
# epoch 18 took 7.9s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.0198
# epoch 19 took 7.3s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0199
# epoch 20 took 7.6s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0199
#
# epoch 1 took 7.9s; av_loss = 0.431; av_test_loss = 0.000; lr = 0.0118
# epoch 2 took 7.9s; av_loss = 0.249; av_test_loss = 0.000; lr = 0.0135
# epoch 3 took 8.1s; av_loss = 0.166; av_test_loss = 0.000; lr = 0.0150
# epoch 4 took 8.0s; av_loss = 0.120; av_test_loss = 0.000; lr = 0.0162
# epoch 5 took 7.5s; av_loss = 0.091; av_test_loss = 0.000; lr = 0.0172
# epoch 6 took 7.9s; av_loss = 0.073; av_test_loss = 0.000; lr = 0.0183
# epoch 7 took 7.4s; av_loss = 0.056; av_test_loss = 0.000; lr = 0.0192
# epoch 8 took 7.8s; av_loss = 0.049; av_test_loss = 0.000; lr = 0.0199
# epoch 9 took 7.8s; av_loss = 0.039; av_test_loss = 0.000; lr = 0.0203
# epoch 10 took 7.6s; av_loss = 0.034; av_test_loss = 0.000; lr = 0.0204
# epoch 11 took 7.5s; av_loss = 0.027; av_test_loss = 0.000; lr = 0.0205
# epoch 12 took 7.4s; av_loss = 0.021; av_test_loss = 0.000; lr = 0.0205
# epoch 13 took 7.6s; av_loss = 0.016; av_test_loss = 0.000; lr = 0.0205
# epoch 14 took 7.4s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.0205
# epoch 15 took 8.3s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.0204
# epoch 16 took 8.0s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0204
# epoch 17 took 7.5s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.0204
# epoch 18 took 7.6s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0204
# epoch 19 took 7.8s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0205
# epoch 20 took 7.8s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0205
#
# epoch 1 took 7.6s; av_loss = 0.422; av_test_loss = 0.000; lr = 0.0118
# epoch 2 took 7.7s; av_loss = 0.250; av_test_loss = 0.000; lr = 0.0135
# epoch 3 took 7.4s; av_loss = 0.165; av_test_loss = 0.000; lr = 0.0150
# epoch 4 took 8.1s; av_loss = 0.120; av_test_loss = 0.000; lr = 0.0162
# epoch 5 took 7.5s; av_loss = 0.092; av_test_loss = 0.000; lr = 0.0168
# epoch 6 took 8.1s; av_loss = 0.073; av_test_loss = 0.000; lr = 0.0176
# epoch 7 took 7.9s; av_loss = 0.061; av_test_loss = 0.000; lr = 0.0181
# epoch 8 took 7.8s; av_loss = 0.049; av_test_loss = 0.000; lr = 0.0186
# epoch 9 took 7.6s; av_loss = 0.039; av_test_loss = 0.000; lr = 0.0192
# epoch 10 took 7.6s; av_loss = 0.034; av_test_loss = 0.000; lr = 0.0194
# epoch 11 took 7.7s; av_loss = 0.026; av_test_loss = 0.000; lr = 0.0195
# epoch 12 took 7.8s; av_loss = 0.022; av_test_loss = 0.000; lr = 0.0195
# epoch 13 took 7.7s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.0195
# epoch 14 took 8.0s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.0196
# epoch 15 took 7.4s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.0196
# epoch 16 took 8.3s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0196
# epoch 17 took 7.6s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.0198
# epoch 18 took 7.5s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.0198
# epoch 19 took 7.7s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0199
# epoch 20 took 7.7s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0200

# %%
torch.manual_seed(123)

#opt_names = []

run_count = 3

for lr in [0.03]:
    opt_name = 'SGD' + '_lr=' + str(lr)
    print(opt_name)
    opt_names.append(opt_name)
    
    losses[model_name][opt_name] = []
    test_losses[model_name][opt_name] = []
    times[model_name][opt_name] = []
    learning_rates[model_name][opt_name] = []
    
    for run in range(run_count):
        losses[model_name][opt_name].append([])
        test_losses[model_name][opt_name].append([])
        times[model_name][opt_name].append([])
        learning_rates[model_name][opt_name].append([])
        
        model = cuda_wrapper(Model(**model_kwargs))
        opt = optim.SGD(model.parameters(), lr=lr)

        av_loss = 0
        av_test_loss = 0
        alpha = 0.999
        global_step = 0

        start_time = time()

        for epoch in range(max_epoch):
            epoch_start_time = time()
            for X, y in train_loader:
                X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                prob = model(X)
                loss = F.nll_loss(prob, y)
                model.zero_grad()
                loss.backward()
                opt.step()
                
                av_loss = alpha * av_loss + (1 - alpha) * loss.data[0]
                losses[model_name][opt_name][run].append(loss.data[0])
                
                learning_rates[model_name][opt_name][run].append(lr)
                times[model_name][opt_name][run].append(time() - start_time)
                
                global_step += 1
                
            if do_validation:
                for X, y in test_loader:
                    X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                
                    av_test_loss = alpha * av_test_loss + (1 - alpha) * loss.data[0]
                    test_losses[model_name][opt_name][run].append(test_loss.data[0])

            print('epoch {} took {:.1f}s; av_loss = {:.3f}; av_test_loss = {:.3f}; lr = {:.4f}'.format(
                epoch+1, time() - epoch_start_time, av_loss, av_test_loss, lr
            ))
        
        print()
        
    losses[model_name][opt_name] = np.array(losses[model_name][opt_name])
    test_losses[model_name][opt_name] = np.array(test_losses[model_name][opt_name])
    times[model_name][opt_name] = np.array(times[model_name][opt_name])
    learning_rates[model_name][opt_name] = np.array(learning_rates[model_name][opt_name])
# Out:
# SGD_lr=0.03
# epoch 1 took 7.8s; av_loss = 0.242; av_test_loss = 0.000; lr = 0.0300
# epoch 2 took 7.8s; av_loss = 0.141; av_test_loss = 0.000; lr = 0.0300
# epoch 3 took 7.7s; av_loss = 0.093; av_test_loss = 0.000; lr = 0.0300
# epoch 4 took 7.5s; av_loss = 0.067; av_test_loss = 0.000; lr = 0.0300
# epoch 5 took 7.5s; av_loss = 0.051; av_test_loss = 0.000; lr = 0.0300
# epoch 6 took 8.1s; av_loss = 0.039; av_test_loss = 0.000; lr = 0.0300
# epoch 7 took 7.6s; av_loss = 0.030; av_test_loss = 0.000; lr = 0.0300
# epoch 8 took 7.8s; av_loss = 0.023; av_test_loss = 0.000; lr = 0.0300
# epoch 9 took 8.2s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.0300
# epoch 10 took 7.5s; av_loss = 0.013; av_test_loss = 0.000; lr = 0.0300
# epoch 11 took 7.7s; av_loss = 0.011; av_test_loss = 0.000; lr = 0.0300
# epoch 12 took 7.8s; av_loss = 0.008; av_test_loss = 0.000; lr = 0.0300
# epoch 13 took 7.9s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0300
# epoch 14 took 8.1s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0300
# epoch 15 took 7.9s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0300
# epoch 16 took 7.8s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 17 took 7.6s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 18 took 7.9s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 19 took 7.9s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 20 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0300
#
# epoch 1 took 7.6s; av_loss = 0.242; av_test_loss = 0.000; lr = 0.0300
# epoch 2 took 7.7s; av_loss = 0.138; av_test_loss = 0.000; lr = 0.0300
# epoch 3 took 8.1s; av_loss = 0.091; av_test_loss = 0.000; lr = 0.0300
# epoch 4 took 7.6s; av_loss = 0.065; av_test_loss = 0.000; lr = 0.0300
# epoch 5 took 8.0s; av_loss = 0.050; av_test_loss = 0.000; lr = 0.0300
# epoch 6 took 7.8s; av_loss = 0.037; av_test_loss = 0.000; lr = 0.0300
# epoch 7 took 7.9s; av_loss = 0.028; av_test_loss = 0.000; lr = 0.0300
# epoch 8 took 7.6s; av_loss = 0.022; av_test_loss = 0.000; lr = 0.0300
# epoch 9 took 7.4s; av_loss = 0.016; av_test_loss = 0.000; lr = 0.0300
# epoch 10 took 7.7s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.0300
# epoch 11 took 7.6s; av_loss = 0.009; av_test_loss = 0.000; lr = 0.0300
# epoch 12 took 7.5s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0300
# epoch 13 took 7.8s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0300
# epoch 14 took 7.5s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0300
# epoch 15 took 8.3s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 16 took 7.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 17 took 7.6s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 18 took 7.3s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 19 took 7.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 20 took 7.6s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0300
#
# epoch 1 took 7.6s; av_loss = 0.238; av_test_loss = 0.000; lr = 0.0300
# epoch 2 took 7.7s; av_loss = 0.137; av_test_loss = 0.000; lr = 0.0300
# epoch 3 took 7.9s; av_loss = 0.090; av_test_loss = 0.000; lr = 0.0300
# epoch 4 took 7.6s; av_loss = 0.065; av_test_loss = 0.000; lr = 0.0300
# epoch 5 took 7.6s; av_loss = 0.049; av_test_loss = 0.000; lr = 0.0300
# epoch 6 took 7.7s; av_loss = 0.037; av_test_loss = 0.000; lr = 0.0300
# epoch 7 took 7.5s; av_loss = 0.029; av_test_loss = 0.000; lr = 0.0300
# epoch 8 took 7.6s; av_loss = 0.022; av_test_loss = 0.000; lr = 0.0300
# epoch 9 took 7.5s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.0300
# epoch 10 took 7.5s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.0300
# epoch 11 took 7.4s; av_loss = 0.008; av_test_loss = 0.000; lr = 0.0300
# epoch 12 took 7.7s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0300
# epoch 13 took 7.4s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0300
# epoch 14 took 7.9s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0300
# epoch 15 took 7.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 16 took 7.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 17 took 7.9s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 18 took 8.0s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 19 took 7.6s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0300
# epoch 20 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0300

# %%
def running_average(a, alpha=0.999):
    #a = np.array(a)
    av = np.zeros_like(a)
    av[0] = a[0]
    for i in range(1, len(a)):
        av[i] = alpha * av[i-1] + (1 - alpha) * a[i]
    return av

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names:
    runs = running_average(losses[model_name][opt_name].T)
    plt.plot(runs.mean(axis=1))
    plt.fill_between(
        np.arange(runs.shape[0]),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
for opt_name in ['SGD_lr=0.05']:
    runs = running_average(losses[model_name][opt_name].T)
    plt.plot(runs.mean(axis=1), 'k--')
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + ['SGD_best'])

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names:
    runs = running_average(losses[model_name][opt_name].T)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1))
    plt.fill_between(
        time_runs.mean(axis=1),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
for opt_name in ['SGD_lr=0.05']:
    runs = running_average(losses[model_name][opt_name].T)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1), 'k--')
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + ['SGD_best'])

# %%
plt.figure(figsize=(15,8))
for opt_name in opt_names:
    runs = running_average(losses[model_name][opt_name].T)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1))
    plt.fill_between(
        time_runs.mean(axis=1),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(opt_names)

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names:
    runs = running_average(learning_rates[model_name][opt_name].T, alpha=0.99)
    plt.plot(runs.mean(axis=1))
    plt.fill_between(
        np.arange(runs.shape[0]),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
#plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names)
