# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms

# %%
from time import time

# %%
USE_CUDA = torch.cuda.is_available()
USE_CUDA
# Out:
# True

# %%
def cuda_wrapper(torch_obj):
    if USE_CUDA:
        return torch_obj.cuda()
    else:
        return torch_obj

# %%
class ModelFullyConnected(nn.Module):

    def __init__(self, num_hidden=1, hidden_size=32, dropout_rate=0.5):
        super(ModelFullyConnected, self).__init__()
        assert num_hidden > 0
        self.input_size = (28, 28)
        self.output_size = 10
        self.num_hidden = num_hidden
        self.dropout_rate = dropout_rate
        self.input_layer = nn.Linear(self.input_size[0] * self.input_size[1], hidden_size)
        self.hidden_layers = nn.ModuleList()
        for _ in range(num_hidden):
            self.hidden_layers.append(nn.Linear(hidden_size, hidden_size))
        self.output_layer = nn.Linear(hidden_size, self.output_size)

    def forward(self, inputs):
        x = inputs.view(-1, self.input_size[0] * self.input_size[1])
        x = F.dropout(F.relu(self.input_layer(x)), p=self.dropout_rate)
        for layer in self.hidden_layers:
            x = F.dropout(F.relu(layer(x)), p=self.dropout_rate)
        x = self.output_layer(x)
        return F.log_softmax(x, dim=1)

# %%
class ModelConvolutional(nn.Module):

    def __init__(self, num_hidden=1, fc_hidden_size=32, dropout_rate=0.5, num_filters=16, filter_size=3):
        super(ModelConvolutional, self).__init__()
        assert num_hidden > 0
        self.input_size = (28, 28)
        self.output_size = 10
        self.num_hidden = num_hidden
        self.num_filters = num_filters
        self.dropout_rate = dropout_rate
        self.input_layer = nn.Conv2d(1, num_filters, filter_size)
        self.hidden_layers = nn.ModuleList()
        for _ in range(num_hidden):
            self.hidden_layers.append(nn.Conv2d(num_filters, num_filters, filter_size))
        self.size_after_convs = (
            self.input_size[0] - (filter_size - 1) * (num_hidden + 1), 
            self.input_size[1] - (filter_size - 1) * (num_hidden + 1)
        )
        self.fc_layer = nn.Linear(self.size_after_convs[0] * self.size_after_convs[1] * num_filters, fc_hidden_size)
        self.output_layer = nn.Linear(fc_hidden_size, self.output_size)

    def forward(self, inputs):
        x = inputs.view(-1, 1, self.input_size[0], self.input_size[1])
        x = F.relu(self.input_layer(x))
        for layer in self.hidden_layers:
            x = F.relu(layer(x))
        x = x.view(-1, self.size_after_convs[0] * self.size_after_convs[1] * self.num_filters)
        #print(x.size())
        x = F.dropout(F.relu(self.fc_layer(x)), p=self.dropout_rate)
        #print(x.size())
        x = self.output_layer(x)
        #print(x.size())
        return F.log_softmax(x, dim=1)

# %%
class AdaSGD2():
    
    def __init__(self, params, init_base_lr=0., init_meta_lr=0., 
                 meta2_lr=1e-3, meta2_betas=(0.9, 0.999), meta2_eps=1e-8):
        self.params = list(params)
        self.base_lr = nn.Parameter(torch.Tensor([init_base_lr]))
        self.base_lr.grad = torch.zeros_like(self.base_lr)
        self.meta_lr = nn.Parameter(torch.Tensor([init_meta_lr]))
        self.meta_lr.grad = torch.zeros_like(self.meta_lr)
        self.meta2_opt = optim.Adam([self.meta_lr], lr=meta2_lr, betas=meta2_betas, eps=meta2_eps)
        self.flat_grads = 0
        self.meta_grads = 0
        
    def step(self):
        grads = []
        for param in self.params:
            grads.append(param.grad.data.view(-1))
        self.flat_grads += torch.cat(grads)
        for param in self.params:
            param.data = param.data - self.base_lr.data[0] * param.grad.data 

    def meta_step(self):
        grads = []
        for param in self.params:
            grads.append(param.grad.data.view(-1))
        flat_grads_new = torch.cat(grads)
        self.base_lr.grad.data = torch.clamp(
            torch.Tensor([-torch.sum(self.flat_grads * flat_grads_new)]), -1, 1
        )
        self.meta_grads += self.base_lr.grad.data
        self.base_lr.data = self.base_lr.data - self.meta_lr.data * self.base_lr.grad.data
        self.flat_grads = 0
        
    def meta2_step(self):
        self.meta2_opt.zero_grad()
        self.meta_lr.grad.data = torch.clamp(
            -self.meta_grads * self.base_lr.grad.data, -1, 1
        )
        self.meta2_opt.step()
        self.meta_grads = 0

# %%
batch_size = 32
test_batch_size = 32
max_epoch = 20
do_validation = False

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if USE_CUDA else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=test_batch_size, shuffle=True, **kwargs)

# %%
losses = {}
test_losses = {}
times = {}
learning_rates = {}

# %%
Model = ModelFullyConnected
model_kwargs = {
    'num_hidden': 2, 
    'hidden_size': 256, 
    'dropout_rate': 0.8
}
model_name = '_'.join(['fc'] + [key + '=' + str(val) for key, val in model_kwargs.items()])
print(model_name)
# Out:
# fc_num_hidden=2_hidden_size=256_dropout_rate=0.8

# %%
losses[model_name] = {}
test_losses[model_name] = {}
times[model_name] = {}
learning_rates[model_name] = {}

# %%
torch.manual_seed(123)

#meta_opt_names = []

run_count = 3

truncated_bptt_step = 2

for meta2_lr in [1e-5, 1e-4]:
    opt_name = 'AdaSGD2' + '_bptt_steps=' + str(truncated_bptt_step) + '_meta2_lr=' + str(meta2_lr)
    print(opt_name)
    meta_opt_names.append(opt_name)
    
    losses[model_name][opt_name] = []
    test_losses[model_name][opt_name] = []
    times[model_name][opt_name] = []
    learning_rates[model_name][opt_name] = []
    
    for run in range(run_count):
        losses[model_name][opt_name].append([])
        test_losses[model_name][opt_name].append([])
        times[model_name][opt_name].append([])
        learning_rates[model_name][opt_name].append([])
        
        model = cuda_wrapper(Model(**model_kwargs))
        opt = AdaSGD2(model.parameters(), meta2_lr=meta2_lr)

        av_loss = 0
        av_test_loss = 0
        alpha = 0.999
        global_step = 0

        start_time = time()

        for epoch in range(max_epoch):
            epoch_start_time = time()
            for X, y in train_loader:
                X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                prob = model(X)
                loss = F.nll_loss(prob, y)
                model.zero_grad()
                do_meta_step = ((global_step + 1) % truncated_bptt_step == 0)
                do_meta2_step = ((global_step + 1) % (truncated_bptt_step ** 2) == 0)
                if do_meta_step:
                    loss.backward(retain_graph=True)
                else:
                    loss.backward()
                opt.step()
                
                av_loss = alpha * av_loss + (1 - alpha) * loss.data[0]
                losses[model_name][opt_name][run].append(loss.data[0])
                
                if do_meta_step:
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                    model.zero_grad()
                    loss.backward()
                    opt.meta_step()
                    
                if do_meta2_step:
                    opt.meta2_step()
                    
                learning_rates[model_name][opt_name][run].append(opt.base_lr.data[0])
                times[model_name][opt_name][run].append(time() - start_time)
                
                global_step += 1
                
            if do_validation:
                for X, y in test_loader:
                    X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                
                    av_test_loss = alpha * av_test_loss + (1 - alpha) * loss.data[0]
                    test_losses[model_name][opt_name][run].append(test_loss.data[0])

            print('epoch {} took {:.1f}s; av_loss = {:.3f}; av_test_loss = {:.3f}; lr = {:.4f}; meta_lr = {:.4f}'.format(
                epoch+1, time() - epoch_start_time, av_loss, av_test_loss, opt.base_lr.data[0], opt.meta_lr.data[0]
            ))
        
        print()
        
    losses[model_name][opt_name] = np.array(losses[model_name][opt_name])
    test_losses[model_name][opt_name] = np.array(test_losses[model_name][opt_name])
    times[model_name][opt_name] = np.array(times[model_name][opt_name])
    learning_rates[model_name][opt_name] = np.array(learning_rates[model_name][opt_name])
# Out:
# AdaSGD2_bptt_steps=2_meta2_lr=1e-05
# epoch 1 took 8.0s; av_loss = 0.313; av_test_loss = 0.000; lr = 0.1361; meta_lr = 0.0024
# epoch 2 took 8.2s; av_loss = 0.142; av_test_loss = 0.000; lr = 0.1639; meta_lr = 0.0031
# epoch 3 took 8.2s; av_loss = 0.086; av_test_loss = 0.000; lr = 0.1652; meta_lr = 0.0037
# epoch 4 took 8.9s; av_loss = 0.063; av_test_loss = 0.000; lr = 0.1755; meta_lr = 0.0040
# epoch 5 took 7.9s; av_loss = 0.045; av_test_loss = 0.000; lr = 0.1617; meta_lr = 0.0041
# epoch 6 took 8.1s; av_loss = 0.033; av_test_loss = 0.000; lr = 0.1554; meta_lr = 0.0045
# epoch 7 took 8.0s; av_loss = 0.030; av_test_loss = 0.000; lr = 0.1612; meta_lr = 0.0046
# epoch 8 took 7.8s; av_loss = 0.020; av_test_loss = 0.000; lr = 0.1510; meta_lr = 0.0049
# epoch 9 took 7.7s; av_loss = 0.016; av_test_loss = 0.000; lr = 0.1348; meta_lr = 0.0054
# epoch 10 took 8.5s; av_loss = 0.011; av_test_loss = 0.000; lr = 0.1298; meta_lr = 0.0057
# epoch 11 took 8.2s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.1307; meta_lr = 0.0057
# epoch 12 took 7.6s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.1323; meta_lr = 0.0057
# epoch 13 took 8.0s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1328; meta_lr = 0.0058
# epoch 14 took 7.8s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.1270; meta_lr = 0.0061
# epoch 15 took 7.7s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1278; meta_lr = 0.0061
# epoch 16 took 8.6s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1239; meta_lr = 0.0063
# epoch 17 took 8.2s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1160; meta_lr = 0.0064
# epoch 18 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1173; meta_lr = 0.0064
# epoch 19 took 7.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1179; meta_lr = 0.0064
# epoch 20 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1183; meta_lr = 0.0064
#
# epoch 1 took 8.0s; av_loss = 0.314; av_test_loss = 0.000; lr = 0.1498; meta_lr = 0.0026
# epoch 2 took 7.8s; av_loss = 0.139; av_test_loss = 0.000; lr = 0.1561; meta_lr = 0.0032
# epoch 3 took 7.5s; av_loss = 0.086; av_test_loss = 0.000; lr = 0.1687; meta_lr = 0.0037
# epoch 4 took 8.4s; av_loss = 0.057; av_test_loss = 0.000; lr = 0.1582; meta_lr = 0.0041
# epoch 5 took 8.3s; av_loss = 0.042; av_test_loss = 0.000; lr = 0.1641; meta_lr = 0.0043
# epoch 6 took 8.4s; av_loss = 0.034; av_test_loss = 0.000; lr = 0.1586; meta_lr = 0.0047
# epoch 7 took 7.5s; av_loss = 0.025; av_test_loss = 0.000; lr = 0.1404; meta_lr = 0.0050
# epoch 8 took 7.3s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.1255; meta_lr = 0.0052
# epoch 9 took 8.3s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.1262; meta_lr = 0.0055
# epoch 10 took 8.2s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.1242; meta_lr = 0.0055
# epoch 11 took 8.5s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1226; meta_lr = 0.0056
# epoch 12 took 8.2s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1157; meta_lr = 0.0056
# epoch 13 took 7.6s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1183; meta_lr = 0.0056
# epoch 14 took 7.9s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1212; meta_lr = 0.0056
# epoch 15 took 7.5s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1181; meta_lr = 0.0058
# epoch 16 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1190; meta_lr = 0.0058
# epoch 17 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1198; meta_lr = 0.0058
# epoch 18 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1207; meta_lr = 0.0058
# epoch 19 took 7.9s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1210; meta_lr = 0.0058
# epoch 20 took 7.4s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1212; meta_lr = 0.0058
#
# epoch 1 took 7.8s; av_loss = 0.299; av_test_loss = 0.000; lr = 0.1282; meta_lr = 0.0025
# epoch 2 took 8.0s; av_loss = 0.137; av_test_loss = 0.000; lr = 0.1538; meta_lr = 0.0031
# epoch 3 took 8.8s; av_loss = 0.086; av_test_loss = 0.000; lr = 0.1554; meta_lr = 0.0035
# epoch 4 took 7.3s; av_loss = 0.061; av_test_loss = 0.000; lr = 0.1679; meta_lr = 0.0037
# epoch 5 took 8.2s; av_loss = 0.047; av_test_loss = 0.000; lr = 0.1525; meta_lr = 0.0041
# epoch 6 took 8.2s; av_loss = 0.032; av_test_loss = 0.000; lr = 0.1442; meta_lr = 0.0046
# epoch 7 took 8.3s; av_loss = 0.025; av_test_loss = 0.000; lr = 0.1484; meta_lr = 0.0047
# epoch 8 took 8.3s; av_loss = 0.019; av_test_loss = 0.000; lr = 0.1520; meta_lr = 0.0047
# epoch 9 took 7.9s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.1377; meta_lr = 0.0051
# epoch 10 took 7.9s; av_loss = 0.013; av_test_loss = 0.000; lr = 0.1324; meta_lr = 0.0054
# epoch 11 took 7.7s; av_loss = 0.008; av_test_loss = 0.000; lr = 0.1321; meta_lr = 0.0055
# epoch 12 took 7.7s; av_loss = 0.005; av_test_loss = 0.000; lr = 0.1280; meta_lr = 0.0057
# epoch 13 took 7.8s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1312; meta_lr = 0.0057
# epoch 14 took 7.6s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.1244; meta_lr = 0.0058
# epoch 15 took 8.6s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1225; meta_lr = 0.0060
# epoch 16 took 8.6s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1150; meta_lr = 0.0062
# epoch 17 took 7.6s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1155; meta_lr = 0.0063
# epoch 18 took 8.0s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1126; meta_lr = 0.0065
# epoch 19 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1139; meta_lr = 0.0065
# epoch 20 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1143; meta_lr = 0.0065
#
# AdaSGD2_bptt_steps=2_meta2_lr=0.0001
# epoch 1 took 7.9s; av_loss = 0.218; av_test_loss = 0.000; lr = 0.1720; meta_lr = 0.0181
# epoch 2 took 7.7s; av_loss = 0.119; av_test_loss = 0.000; lr = 0.1651; meta_lr = 0.0248
# epoch 3 took 8.1s; av_loss = 0.083; av_test_loss = 0.000; lr = 0.1897; meta_lr = 0.0282
# epoch 4 took 8.1s; av_loss = 0.054; av_test_loss = 0.000; lr = 0.1999; meta_lr = 0.0326
# epoch 5 took 8.6s; av_loss = 0.042; av_test_loss = 0.000; lr = 0.2036; meta_lr = 0.0363
# epoch 6 took 7.9s; av_loss = 0.032; av_test_loss = 0.000; lr = 0.1351; meta_lr = 0.0403
# epoch 7 took 8.2s; av_loss = 0.022; av_test_loss = 0.000; lr = 0.1335; meta_lr = 0.0429
# epoch 8 took 8.5s; av_loss = 0.014; av_test_loss = 0.000; lr = 0.1681; meta_lr = 0.0454
# epoch 9 took 8.2s; av_loss = 0.015; av_test_loss = 0.000; lr = 0.1547; meta_lr = 0.0459
# epoch 10 took 7.9s; av_loss = 0.009; av_test_loss = 0.000; lr = 0.0867; meta_lr = 0.0510
# epoch 11 took 7.9s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1300; meta_lr = 0.0516
# epoch 12 took 8.2s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.1579; meta_lr = 0.0516
# epoch 13 took 8.7s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1388; meta_lr = 0.0516
# epoch 14 took 8.3s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1278; meta_lr = 0.0537
# epoch 15 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1414; meta_lr = 0.0537
# epoch 16 took 8.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1470; meta_lr = 0.0537
# epoch 17 took 7.9s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1498; meta_lr = 0.0537
# epoch 18 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1522; meta_lr = 0.0537
# epoch 19 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1539; meta_lr = 0.0537
# epoch 20 took 8.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1552; meta_lr = 0.0537
#
# epoch 1 took 9.2s; av_loss = 0.224; av_test_loss = 0.000; lr = 0.1808; meta_lr = 0.0206
# epoch 2 took 8.1s; av_loss = 0.125; av_test_loss = 0.000; lr = 0.1977; meta_lr = 0.0269
# epoch 3 took 7.7s; av_loss = 0.079; av_test_loss = 0.000; lr = 0.1754; meta_lr = 0.0324
# epoch 4 took 8.5s; av_loss = 0.055; av_test_loss = 0.000; lr = 0.1622; meta_lr = 0.0375
# epoch 5 took 7.9s; av_loss = 0.040; av_test_loss = 0.000; lr = 0.1781; meta_lr = 0.0387
# epoch 6 took 7.9s; av_loss = 0.031; av_test_loss = 0.000; lr = 0.1565; meta_lr = 0.0406
# epoch 7 took 7.7s; av_loss = 0.023; av_test_loss = 0.000; lr = 0.1630; meta_lr = 0.0441
# epoch 8 took 7.6s; av_loss = 0.019; av_test_loss = 0.000; lr = 0.1548; meta_lr = 0.0450
# epoch 9 took 7.8s; av_loss = 0.013; av_test_loss = 0.000; lr = 0.1472; meta_lr = 0.0474
# epoch 10 took 7.9s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.1545; meta_lr = 0.0494
# epoch 11 took 8.0s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.1506; meta_lr = 0.0494
# epoch 12 took 7.9s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.1318; meta_lr = 0.0513
# epoch 13 took 8.3s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1450; meta_lr = 0.0513
# epoch 14 took 8.2s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1549; meta_lr = 0.0514
# epoch 15 took 8.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1587; meta_lr = 0.0514
# epoch 16 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1635; meta_lr = 0.0514
# epoch 17 took 8.4s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1655; meta_lr = 0.0514
# epoch 18 took 8.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1682; meta_lr = 0.0514
# epoch 19 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1696; meta_lr = 0.0514
# epoch 20 took 8.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1710; meta_lr = 0.0514
#
# epoch 1 took 7.6s; av_loss = 0.223; av_test_loss = 0.000; lr = 0.1550; meta_lr = 0.0190
# epoch 2 took 8.3s; av_loss = 0.124; av_test_loss = 0.000; lr = 0.1959; meta_lr = 0.0242
# epoch 3 took 8.7s; av_loss = 0.077; av_test_loss = 0.000; lr = 0.2150; meta_lr = 0.0298
# epoch 4 took 7.8s; av_loss = 0.056; av_test_loss = 0.000; lr = 0.2036; meta_lr = 0.0335
# epoch 5 took 8.0s; av_loss = 0.041; av_test_loss = 0.000; lr = 0.2027; meta_lr = 0.0365
# epoch 6 took 7.8s; av_loss = 0.037; av_test_loss = 0.000; lr = 0.1583; meta_lr = 0.0408
# epoch 7 took 8.0s; av_loss = 0.027; av_test_loss = 0.000; lr = 0.1776; meta_lr = 0.0425
# epoch 8 took 7.9s; av_loss = 0.016; av_test_loss = 0.000; lr = 0.1727; meta_lr = 0.0459
# epoch 9 took 8.1s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.0908; meta_lr = 0.0469
# epoch 10 took 8.5s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.1408; meta_lr = 0.0480
# epoch 11 took 8.1s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0971; meta_lr = 0.0484
# epoch 12 took 8.1s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0994; meta_lr = 0.0484
# epoch 13 took 8.0s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.1244; meta_lr = 0.0484
# epoch 14 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1398; meta_lr = 0.0484
# epoch 15 took 7.8s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1451; meta_lr = 0.0484
# epoch 16 took 7.6s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1473; meta_lr = 0.0484
# epoch 17 took 9.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1507; meta_lr = 0.0484
# epoch 18 took 8.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1521; meta_lr = 0.0484
# epoch 19 took 8.6s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1545; meta_lr = 0.0484
# epoch 20 took 8.0s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.1564; meta_lr = 0.0484

# %%
meta_opt_names = meta_opt_names[:-1]

# %%
torch.manual_seed(123)

#opt_names = []

run_count = 3

for lr in [0.05]:
    opt_name = 'SGD' + '_lr=' + str(lr)
    print(opt_name)
    opt_names.append(opt_name)
    
    losses[model_name][opt_name] = []
    test_losses[model_name][opt_name] = []
    times[model_name][opt_name] = []
    learning_rates[model_name][opt_name] = []
    
    for run in range(run_count):
        losses[model_name][opt_name].append([])
        test_losses[model_name][opt_name].append([])
        times[model_name][opt_name].append([])
        learning_rates[model_name][opt_name].append([])
        
        model = cuda_wrapper(Model(**model_kwargs))
        opt = optim.SGD(model.parameters(), lr=lr)

        av_loss = 0
        av_test_loss = 0
        alpha = 0.999
        global_step = 0

        start_time = time()

        for epoch in range(max_epoch):
            epoch_start_time = time()
            for X, y in train_loader:
                X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                prob = model(X)
                loss = F.nll_loss(prob, y)
                model.zero_grad()
                loss.backward()
                opt.step()
                
                av_loss = alpha * av_loss + (1 - alpha) * loss.data[0]
                losses[model_name][opt_name][run].append(loss.data[0])
                
                learning_rates[model_name][opt_name][run].append(lr)
                times[model_name][opt_name][run].append(time() - start_time)
                
                global_step += 1
                
            if do_validation:
                for X, y in test_loader:
                    X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                
                    av_test_loss = alpha * av_test_loss + (1 - alpha) * loss.data[0]
                    test_losses[model_name][opt_name][run].append(test_loss.data[0])

            print('epoch {} took {:.1f}s; av_loss = {:.3f}; av_test_loss = {:.3f}; lr = {:.4f}'.format(
                epoch+1, time() - epoch_start_time, av_loss, av_test_loss, lr
            ))
        
        print()
        
    losses[model_name][opt_name] = np.array(losses[model_name][opt_name])
    test_losses[model_name][opt_name] = np.array(test_losses[model_name][opt_name])
    times[model_name][opt_name] = np.array(times[model_name][opt_name])
    learning_rates[model_name][opt_name] = np.array(learning_rates[model_name][opt_name])
# Out:
# SGD_lr=0.05
# epoch 1 took 7.2s; av_loss = 0.193; av_test_loss = 0.000; lr = 0.0500
# epoch 2 took 7.3s; av_loss = 0.116; av_test_loss = 0.000; lr = 0.0500
# epoch 3 took 7.2s; av_loss = 0.076; av_test_loss = 0.000; lr = 0.0500
# epoch 4 took 7.9s; av_loss = 0.054; av_test_loss = 0.000; lr = 0.0500
# epoch 5 took 7.5s; av_loss = 0.041; av_test_loss = 0.000; lr = 0.0500
# epoch 6 took 7.2s; av_loss = 0.029; av_test_loss = 0.000; lr = 0.0500
# epoch 7 took 7.2s; av_loss = 0.023; av_test_loss = 0.000; lr = 0.0500
# epoch 8 took 7.2s; av_loss = 0.018; av_test_loss = 0.000; lr = 0.0500
# epoch 9 took 7.7s; av_loss = 0.013; av_test_loss = 0.000; lr = 0.0500
# epoch 10 took 7.2s; av_loss = 0.010; av_test_loss = 0.000; lr = 0.0500
# epoch 11 took 7.5s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0500
# epoch 12 took 7.2s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0500
# epoch 13 took 7.6s; av_loss = 0.003; av_test_loss = 0.000; lr = 0.0500
# epoch 14 took 7.2s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0500
# epoch 15 took 7.2s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0500
# epoch 16 took 7.8s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0500
# epoch 17 took 7.6s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 18 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 19 took 7.5s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 20 took 7.5s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
#
# epoch 1 took 8.1s; av_loss = 0.194; av_test_loss = 0.000; lr = 0.0500
# epoch 2 took 7.7s; av_loss = 0.114; av_test_loss = 0.000; lr = 0.0500
# epoch 3 took 7.9s; av_loss = 0.076; av_test_loss = 0.000; lr = 0.0500
# epoch 4 took 7.3s; av_loss = 0.053; av_test_loss = 0.000; lr = 0.0500
# epoch 5 took 7.3s; av_loss = 0.041; av_test_loss = 0.000; lr = 0.0500
# epoch 6 took 7.4s; av_loss = 0.030; av_test_loss = 0.000; lr = 0.0500
# epoch 7 took 7.5s; av_loss = 0.020; av_test_loss = 0.000; lr = 0.0500
# epoch 8 took 7.6s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.0500
# epoch 9 took 7.5s; av_loss = 0.012; av_test_loss = 0.000; lr = 0.0500
# epoch 10 took 7.4s; av_loss = 0.008; av_test_loss = 0.000; lr = 0.0500
# epoch 11 took 7.8s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0500
# epoch 12 took 7.6s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.0500
# epoch 13 took 7.3s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0500
# epoch 14 took 7.6s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0500
# epoch 15 took 7.2s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 16 took 7.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 17 took 7.3s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 18 took 7.2s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 19 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 20 took 7.7s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
#
# epoch 1 took 7.2s; av_loss = 0.191; av_test_loss = 0.000; lr = 0.0500
# epoch 2 took 7.4s; av_loss = 0.112; av_test_loss = 0.000; lr = 0.0500
# epoch 3 took 7.6s; av_loss = 0.074; av_test_loss = 0.000; lr = 0.0500
# epoch 4 took 7.8s; av_loss = 0.054; av_test_loss = 0.000; lr = 0.0500
# epoch 5 took 7.3s; av_loss = 0.040; av_test_loss = 0.000; lr = 0.0500
# epoch 6 took 7.6s; av_loss = 0.031; av_test_loss = 0.000; lr = 0.0500
# epoch 7 took 7.3s; av_loss = 0.023; av_test_loss = 0.000; lr = 0.0500
# epoch 8 took 7.5s; av_loss = 0.017; av_test_loss = 0.000; lr = 0.0500
# epoch 9 took 7.3s; av_loss = 0.013; av_test_loss = 0.000; lr = 0.0500
# epoch 10 took 7.6s; av_loss = 0.008; av_test_loss = 0.000; lr = 0.0500
# epoch 11 took 8.3s; av_loss = 0.007; av_test_loss = 0.000; lr = 0.0500
# epoch 12 took 7.1s; av_loss = 0.006; av_test_loss = 0.000; lr = 0.0500
# epoch 13 took 7.2s; av_loss = 0.004; av_test_loss = 0.000; lr = 0.0500
# epoch 14 took 7.2s; av_loss = 0.002; av_test_loss = 0.000; lr = 0.0500
# epoch 15 took 7.2s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0500
# epoch 16 took 7.7s; av_loss = 0.001; av_test_loss = 0.000; lr = 0.0500
# epoch 17 took 7.5s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 18 took 7.4s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 19 took 7.4s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500
# epoch 20 took 8.1s; av_loss = 0.000; av_test_loss = 0.000; lr = 0.0500

# %%
def running_average(a, alpha=0.999):
    #a = np.array(a)
    av = np.zeros_like(a)
    av[0] = a[0]
    for i in range(1, len(a)):
        av[i] = alpha * av[i-1] + (1 - alpha) * a[i]
    return av

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names:
    runs = running_average(losses[model_name][opt_name].T)
    plt.plot(runs.mean(axis=1))
    plt.fill_between(
        np.arange(runs.shape[0]),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
for opt_name in ['SGD_lr=0.05']:
    runs = running_average(losses[model_name][opt_name].T)
    plt.plot(runs.mean(axis=1), 'k--')
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + ['SGD_best'])

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names:
    runs = running_average(losses[model_name][opt_name].T)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1))
    plt.fill_between(
        time_runs.mean(axis=1),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
for opt_name in ['SGD_lr=0.05']:
    runs = running_average(losses[model_name][opt_name].T)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1), 'k--')
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + ['SGD_best'])

# %%
plt.figure(figsize=(15,8))
for opt_name in opt_names:
    runs = running_average(losses[model_name][opt_name].T)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1))
    plt.fill_between(
        time_runs.mean(axis=1),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(opt_names)

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names:
    runs = running_average(learning_rates[model_name][opt_name].T, alpha=0.99)
    plt.plot(runs.mean(axis=1))
    plt.fill_between(
        np.arange(runs.shape[0]),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
#plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names)
