# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms

# %%
from data import get_batch
from meta_optimizer import MetaModel, FastMetaOptimizer, MetaOptimizer, LearningRateOnlyMetaOptimizer
from model import ModelBasic, ModelFullyConnected, ModelConvolutional
from utils import copy_params
from time import time

# %%
USE_CUDA = torch.cuda.is_available()
USE_CUDA
# Out:
# True

# %%
def cuda_wrapper(torch_obj):
    if USE_CUDA:
        return torch_obj.cuda()
    else:
        return torch_obj

# %%
losses = {}
test_losses = {}
times = {}

# %%
batch_size = 32
test_batch_size = 32
truncated_bptt_step = 75
max_epoch = 20
fast_meta_opt = False
lr_only = True
replay_trajectory = False
num_layers = 2
hidden_size = 10
do_validation = True

# %%
kwargs = {'num_workers': 1, 'pin_memory': True} if USE_CUDA else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=test_batch_size, shuffle=True, **kwargs)

# %%
Model = ModelConvolutional
num_hidden = 2
model_kwargs = {
    'num_hidden': num_hidden, 
    'fc_hidden_size': 256, 
    'dropout_rate': 0.5, 
    'num_filters': 16, 
    'filter_size': 3
}
model_name = 'conv' + '_num_hidden=' + str(num_hidden)
#model_name = '_'.join(['fc'] + [key + '=' + str(val) for key, val in model_kwargs.items()])
print(model_name)

# %%
Model = ModelFullyConnected
num_hidden = 2
model_kwargs = {
    'num_hidden': num_hidden, 
    'hidden_size': 256, 
    'dropout_rate': 0.8
}
model_name = '_'.join(['fc'] + [key + '=' + str(val) for key, val in model_kwargs.items()])
print(model_name)

# %%
losses[model_name] = {}
test_losses[model_name] = {}
times[model_name] = {}
# Out:
# fc_num_hidden=2_hidden_size=256_dropout_rate=0.8

# %%
torch.manual_seed(123)

meta_opt_names = []

run_count = 5

opt_name = 'meta' + '_bptt_steps=' + str(truncated_bptt_step) + '_batch_size=' + str(batch_size)
meta_opt_names.append(opt_name)

losses[model_name][opt_name] = []
test_losses[model_name][opt_name] = []
times[model_name][opt_name] = []
    
for run in range(run_count):
    losses[model_name][opt_name].append([])
    test_losses[model_name][opt_name].append([])
    times[model_name][opt_name].append([])
    
    # Create a meta optimizer that wraps a model into a meta model
    # to keep track of the meta updates.
    meta_model = cuda_wrapper(Model(**model_kwargs))

    if lr_only:
        meta_optimizer = cuda_wrapper(LearningRateOnlyMetaOptimizer(MetaModel(meta_model), num_layers, hidden_size))
    elif fast_meta_opt:
        meta_optimizer = cuda_wrapper(FastMetaOptimizer(MetaModel(meta_model), num_layers, hidden_size))
    else:
        meta_optimizer = cuda_wrapper(MetaOptimizer(MetaModel(meta_model), num_layers, hidden_size))

    optimizer = optim.Adam(meta_optimizer.parameters())

    # Sample a new model
    model = cuda_wrapper(Model(**model_kwargs))
            
    if replay_trajectory:
        backup_model = cuda_wrapper(Model(**model_kwargs))

    d = 1

    start_time = time()
    
    av_loss = 0
    av_test_loss = 0
    alpha = 0.999
    
    print('run {} of {}'.format(run + 1, run_count))

    for epoch in range(max_epoch):
        cum_loss = 0.
        step_count = 0
        for step, (x, y) in enumerate(train_loader):
            if step % truncated_bptt_step == 0:
                # Keep states for truncated BPTT
                meta_optimizer.reset_lstm(
                    keep_states=((step>0) or (epoch>0)), model=model, use_cuda=USE_CUDA
                )

                if replay_trajectory:
                    #meta_optimizer.backup_model_params()
                    copy_params(source=model, dest=backup_model)
                    
                #loss_sum = Variable(cuda_wrapper(torch.zeros(1)), requires_grad=True)
            
            x, y = Variable(cuda_wrapper(x)), Variable(cuda_wrapper(y))

            # First we need to compute the gradients of the model
            f_x = model(x)
            loss = F.nll_loss(f_x, y)
            model.zero_grad()
            loss.backward()

            if not replay_trajectory:
                cum_loss += loss.data[0]
                losses[model_name][opt_name][run].append(loss.data[0])
                av_loss = alpha * av_loss + (1 - alpha) * loss.data[0]
                
            # Perfom a meta update using gradients from model
            # and return the current meta model saved in the optimizer
            meta_model = meta_optimizer.meta_update(model, loss.data)

            # Compute a loss for a step the meta optimizer
            f_x = meta_model(x)
            loss = F.nll_loss(f_x, y)

            #loss_sum = loss_sum + loss

            if (step + 1) % truncated_bptt_step == 0:
                # Update the parameters of the meta optimizer
                meta_optimizer.zero_grad()
                #loss_sum.backward()     # Optimize the sum of losses on the trajectory, or just the last loss?
                loss.backward()
                for param in meta_optimizer.parameters():
                    param.grad.data.clamp_(-1, 1)
                optimizer.step()
                
                if replay_trajectory:
                    meta_optimizer.reset_lstm(
                        keep_states=((step>0) or (epoch>0)), model=model, use_cuda=USE_CUDA
                    )
                    copy_params(source=backup_model, dest=model)

                    for j in range(truncated_bptt_step):
                        train_iter = iter(train_loader)
                        try:
                            x, y = next(train_iter)
                        except StopIteration:
                            train_iter = iter(train_loader)
                            x, y = next(train_iter)

                        x, y = Variable(cuda_wrapper(x)), Variable(cuda_wrapper(y))

                        # First we need to compute the gradients of the model
                        f_x = model(x)
                        loss = F.nll_loss(f_x, y)
                        model.zero_grad()
                        loss.backward()

                        # Perfom a meta update using gradients from model
                        # and return the current meta model saved in the optimizer
                        meta_model = meta_optimizer.meta_update(model, loss.data)
                        
                        cum_loss += loss.data[0]
                        losses[model_name][opt_name][run].append(loss.data[0])
                        
            step_count += 1
            times[model_name][opt_name][run].append(time() - start_time)

        #av_loss = cum_loss / step_count

        # Validation:
        if do_validation:
            cum_test_loss = 0.
            step_count = 0
            for step, (x, y) in enumerate(test_loader):
                x, y = Variable(cuda_wrapper(x)), Variable(cuda_wrapper(y))
        
                f_x = model(x)
                loss = F.nll_loss(f_x, y)
            
                cum_test_loss += loss.data[0]
                test_losses[model_name][opt_name][run].append(loss.data[0])
                av_test_loss = alpha * av_test_loss + (1 - alpha) * loss.data[0]
            
                step_count += 1
            #av_test_loss = cum_test_loss / step_count
        
        if lr_only:
            meta_optimizer.learning_rate.clamp(min=1e-8)
            print('epoch {}; av_loss = {:.3f}; av_test_loss = {:.3f}; lr = {:.4f}'.format(
                epoch+1, av_loss, av_test_loss, meta_optimizer.learning_rate.data[0]
            ))
        else:
            print('epoch {}; av_loss = {:.3f}; av_test_loss = {:.3f}'.format(epoch+1, av_loss, av_test_loss))
        if av_loss < 0.1**d:
            print(
                'model reached loss < 1e-{} in {} epochs ({:.1f}s)'.format(
                    d, epoch+1, time() - start_time
                )
            )
            #if d >= 3:
            #    break
            d += 1
    print()
            
losses[model_name][opt_name] = np.array(losses[model_name][opt_name])
test_losses[model_name][opt_name] = np.array(test_losses[model_name][opt_name])
times[model_name][opt_name] = np.array(times[model_name][opt_name])
# Out:
# run 1 of 5
# epoch 1; av_loss = 0.162; av_test_loss = 0.029; lr = 0.1085
# epoch 2; av_loss = 0.102; av_test_loss = 0.044; lr = 0.1078
# epoch 3; av_loss = 0.069; av_test_loss = 0.056; lr = 0.1058
# model reached loss < 1e-1 in 3 epochs (38.3s)
# epoch 4; av_loss = 0.050; av_test_loss = 0.061; lr = 0.1050
# epoch 5; av_loss = 0.039; av_test_loss = 0.068; lr = 0.1043
# epoch 6; av_loss = 0.028; av_test_loss = 0.071; lr = 0.1039
# epoch 7; av_loss = 0.024; av_test_loss = 0.073; lr = 0.1016
# epoch 8; av_loss = 0.018; av_test_loss = 0.073; lr = 0.1006
# epoch 9; av_loss = 0.014; av_test_loss = 0.076; lr = 0.0998
# epoch 10; av_loss = 0.009; av_test_loss = 0.076; lr = 0.0945
# model reached loss < 1e-2 in 10 epochs (124.8s)
# epoch 11; av_loss = 0.005; av_test_loss = 0.077; lr = 0.0929
# epoch 12; av_loss = 0.004; av_test_loss = 0.076; lr = 0.0930
# epoch 13; av_loss = 0.001; av_test_loss = 0.075; lr = 0.0931
# epoch 14; av_loss = 0.000; av_test_loss = 0.075; lr = 0.0933
# model reached loss < 1e-3 in 14 epochs (173.9s)
# epoch 15; av_loss = 0.000; av_test_loss = 0.076; lr = 0.0933
# epoch 16; av_loss = 0.000; av_test_loss = 0.076; lr = 0.0933
# epoch 17; av_loss = 0.000; av_test_loss = 0.077; lr = 0.0934
# model reached loss < 1e-4 in 17 epochs (209.6s)
# epoch 18; av_loss = 0.000; av_test_loss = 0.078; lr = 0.0934
# epoch 19; av_loss = 0.000; av_test_loss = 0.079; lr = 0.0934
# epoch 20; av_loss = 0.000; av_test_loss = 0.080; lr = 0.0934
#
# run 2 of 5
# epoch 1; av_loss = 0.161; av_test_loss = 0.033; lr = 0.0997
# epoch 2; av_loss = 0.100; av_test_loss = 0.048; lr = 0.0991
# epoch 3; av_loss = 0.068; av_test_loss = 0.057; lr = 0.0997
# model reached loss < 1e-1 in 3 epochs (36.8s)
# epoch 4; av_loss = 0.047; av_test_loss = 0.060; lr = 0.0993
# epoch 5; av_loss = 0.034; av_test_loss = 0.068; lr = 0.0961
# epoch 6; av_loss = 0.027; av_test_loss = 0.070; lr = 0.0942
# epoch 7; av_loss = 0.020; av_test_loss = 0.072; lr = 0.0966
# epoch 8; av_loss = 0.017; av_test_loss = 0.079; lr = 0.0964
# epoch 9; av_loss = 0.016; av_test_loss = 0.082; lr = 0.0961
# epoch 10; av_loss = 0.014; av_test_loss = 0.079; lr = 0.0946
# epoch 11; av_loss = 0.008; av_test_loss = 0.079; lr = 0.0944
# model reached loss < 1e-2 in 11 epochs (132.4s)
# epoch 12; av_loss = 0.010; av_test_loss = 0.082; lr = 0.0940
# epoch 13; av_loss = 0.007; av_test_loss = 0.085; lr = 0.0938
# epoch 14; av_loss = 0.006; av_test_loss = 0.085; lr = 0.0933
# epoch 15; av_loss = 0.007; av_test_loss = 0.090; lr = 0.0931
# epoch 16; av_loss = 0.005; av_test_loss = 0.088; lr = 0.0925
# epoch 17; av_loss = 0.003; av_test_loss = 0.086; lr = 0.0915
# epoch 18; av_loss = 0.001; av_test_loss = 0.084; lr = 0.0912
# model reached loss < 1e-3 in 18 epochs (219.2s)
# epoch 19; av_loss = 0.000; av_test_loss = 0.083; lr = 0.0912
# epoch 20; av_loss = 0.000; av_test_loss = 0.082; lr = 0.0912
#
# run 3 of 5
# epoch 1; av_loss = 0.160; av_test_loss = 0.028; lr = 0.0964
# epoch 2; av_loss = 0.102; av_test_loss = 0.044; lr = 0.0975
# epoch 3; av_loss = 0.066; av_test_loss = 0.051; lr = 0.0893
# model reached loss < 1e-1 in 3 epochs (36.8s)
# epoch 4; av_loss = 0.044; av_test_loss = 0.055; lr = 0.0873
# epoch 5; av_loss = 0.032; av_test_loss = 0.058; lr = 0.0878
# epoch 6; av_loss = 0.027; av_test_loss = 0.068; lr = 0.0874
# epoch 7; av_loss = 0.019; av_test_loss = 0.073; lr = 0.0869
# epoch 8; av_loss = 0.014; av_test_loss = 0.077; lr = 0.0871
# epoch 9; av_loss = 0.014; av_test_loss = 0.079; lr = 0.0870
# epoch 10; av_loss = 0.012; av_test_loss = 0.085; lr = 0.0873
# epoch 11; av_loss = 0.011; av_test_loss = 0.083; lr = 0.0870
# epoch 12; av_loss = 0.008; av_test_loss = 0.080; lr = 0.0870
# model reached loss < 1e-2 in 12 epochs (148.8s)
# epoch 13; av_loss = 0.005; av_test_loss = 0.080; lr = 0.0871
# epoch 14; av_loss = 0.006; av_test_loss = 0.081; lr = 0.0870
# epoch 15; av_loss = 0.003; av_test_loss = 0.081; lr = 0.0869
# epoch 16; av_loss = 0.001; av_test_loss = 0.082; lr = 0.0870
# epoch 17; av_loss = 0.000; av_test_loss = 0.082; lr = 0.0871
# model reached loss < 1e-3 in 17 epochs (210.4s)
# epoch 18; av_loss = 0.000; av_test_loss = 0.083; lr = 0.0871
# epoch 19; av_loss = 0.000; av_test_loss = 0.084; lr = 0.0871
# model reached loss < 1e-4 in 19 epochs (234.9s)
# epoch 20; av_loss = 0.000; av_test_loss = 0.085; lr = 0.0872
#
# run 4 of 5
# epoch 1; av_loss = 0.161; av_test_loss = 0.040; lr = 0.1102
# epoch 2; av_loss = 0.102; av_test_loss = 0.049; lr = 0.1132
# epoch 3; av_loss = 0.069; av_test_loss = 0.057; lr = 0.1060
# model reached loss < 1e-1 in 3 epochs (36.1s)
# epoch 4; av_loss = 0.046; av_test_loss = 0.062; lr = 0.1038
# epoch 5; av_loss = 0.035; av_test_loss = 0.063; lr = 0.1057
# epoch 6; av_loss = 0.028; av_test_loss = 0.065; lr = 0.1021
# epoch 7; av_loss = 0.019; av_test_loss = 0.069; lr = 0.0984
# epoch 8; av_loss = 0.015; av_test_loss = 0.071; lr = 0.0970
# epoch 9; av_loss = 0.009; av_test_loss = 0.071; lr = 0.0945
# model reached loss < 1e-2 in 9 epochs (108.4s)
# epoch 10; av_loss = 0.007; av_test_loss = 0.075; lr = 0.0938
# epoch 11; av_loss = 0.009; av_test_loss = 0.079; lr = 0.0937
# epoch 12; av_loss = 0.006; av_test_loss = 0.078; lr = 0.0935
# epoch 13; av_loss = 0.008; av_test_loss = 0.085; lr = 0.0930
# epoch 14; av_loss = 0.006; av_test_loss = 0.083; lr = 0.0923
# epoch 15; av_loss = 0.004; av_test_loss = 0.086; lr = 0.0923
# epoch 16; av_loss = 0.002; av_test_loss = 0.085; lr = 0.0922
# epoch 17; av_loss = 0.001; av_test_loss = 0.084; lr = 0.0923
# model reached loss < 1e-3 in 17 epochs (205.1s)
# epoch 18; av_loss = 0.000; av_test_loss = 0.084; lr = 0.0923
# epoch 19; av_loss = 0.000; av_test_loss = 0.084; lr = 0.0924
# model reached loss < 1e-4 in 19 epochs (228.6s)
# epoch 20; av_loss = 0.000; av_test_loss = 0.084; lr = 0.0924
#
# run 5 of 5
# epoch 1; av_loss = 0.166; av_test_loss = 0.029; lr = 0.1117
# epoch 2; av_loss = 0.101; av_test_loss = 0.046; lr = 0.1102
# epoch 3; av_loss = 0.067; av_test_loss = 0.055; lr = 0.1108
# model reached loss < 1e-1 in 3 epochs (35.9s)
# epoch 4; av_loss = 0.050; av_test_loss = 0.061; lr = 0.1088
# epoch 5; av_loss = 0.034; av_test_loss = 0.063; lr = 0.1078
# epoch 6; av_loss = 0.027; av_test_loss = 0.069; lr = 0.1075
# epoch 7; av_loss = 0.020; av_test_loss = 0.078; lr = 0.1012
# epoch 8; av_loss = 0.014; av_test_loss = 0.077; lr = 0.0993
# epoch 9; av_loss = 0.012; av_test_loss = 0.080; lr = 0.0985
# epoch 10; av_loss = 0.009; av_test_loss = 0.084; lr = 0.0979
# model reached loss < 1e-2 in 10 epochs (119.4s)
# epoch 11; av_loss = 0.010; av_test_loss = 0.082; lr = 0.0975
# epoch 12; av_loss = 0.005; av_test_loss = 0.082; lr = 0.0971
# epoch 13; av_loss = 0.002; av_test_loss = 0.080; lr = 0.0970
# epoch 14; av_loss = 0.001; av_test_loss = 0.079; lr = 0.0971
# model reached loss < 1e-3 in 14 epochs (168.8s)
# epoch 15; av_loss = 0.000; av_test_loss = 0.078; lr = 0.0972
# epoch 16; av_loss = 0.000; av_test_loss = 0.078; lr = 0.0972
# epoch 17; av_loss = 0.000; av_test_loss = 0.079; lr = 0.0972
# epoch 18; av_loss = 0.000; av_test_loss = 0.080; lr = 0.0972
# model reached loss < 1e-4 in 18 epochs (216.9s)
# epoch 19; av_loss = 0.000; av_test_loss = 0.080; lr = 0.0972
# epoch 20; av_loss = 0.000; av_test_loss = 0.081; lr = 0.0973

# %%
torch.manual_seed(123)

opt_name_prefixes = ['adam', 'momentum', 'sgd']
opt_names = []

run_count = 5

for name_prefix in opt_name_prefixes:
    print('{}:'.format(name_prefix))
    opt_name = name_prefix + '_batch_size=' + str(batch_size)
    opt_names.append(opt_name)

    losses[model_name][opt_name] = []
    test_losses[model_name][opt_name] = []
    times[model_name][opt_name] = []
    
    for run in range(run_count):
        print('run {} of {}'.format(run + 1, run_count))
        start_time = time()
        model = cuda_wrapper(Model(**model_kwargs))
        if name_prefix == 'sgd':
            opt = optim.SGD(model.parameters(), lr=1e-2)
        elif name_prefix == 'momentum':
            opt = optim.SGD(model.parameters(), lr=1e-2, momentum=0.9)
        elif name_prefix == 'adam':
            opt = optim.Adam(model.parameters())
        losses[model_name][opt_name].append([])
        test_losses[model_name][opt_name].append([])
        times[model_name][opt_name].append([])
        alpha = 0.999
        av_loss = 0
        av_test_loss = 0
        for epoch in range(max_epoch * 2):
            cum_loss = 0.
            step_count = 0
            for X, y in train_loader:
                model.zero_grad()
                X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                prob = model(X)
                loss = F.nll_loss(prob, y)
                loss.backward()
                opt.step()
                losses[model_name][opt_name][run].append(loss.data[0])
                cum_loss += loss.data[0]
                av_loss = alpha * av_loss + (1 - alpha) * loss.data[0]
                step_count += 1
                times[model_name][opt_name][run].append(time() - start_time)
            #av_loss = cum_loss / step_count

            if do_validation:
                cum_test_loss = 0.
                step_count = 0
                for X, y in test_loader:
                    X, y = Variable(cuda_wrapper(X)), Variable(cuda_wrapper(y))
                    prob = model(X)
                    loss = F.nll_loss(prob, y)
                    test_losses[model_name][opt_name][run].append(loss.data[0])
                    cum_test_loss += loss.data[0]
                    av_test_loss = alpha * av_test_loss + (1 - alpha) * loss.data[0]
                    step_count += 1
                #av_test_loss = cum_test_loss / step_count    
        
            print('Epoch {}; av_loss = {:.3f}; av_test_loss = {:.3f}'.format(
                epoch+1, av_loss, av_test_loss
            ))
        print()
        
    print()
    
    losses[model_name][opt_name] = np.array(losses[model_name][opt_name])
    test_losses[model_name][opt_name] = np.array(test_losses[model_name][opt_name])
    times[model_name][opt_name] = np.array(times[model_name][opt_name])
# Out:
# adam:
# run 1 of 5
# Epoch 1; av_loss = 0.153; av_test_loss = 0.035

# %%
def running_average(a, alpha=0.99):
    #a = np.array(a)
    av = np.zeros_like(a)
    av[0] = a[0]
    for i in range(1, len(a)):
        av[i] = alpha * av[i-1] + (1 - alpha) * a[i]
    return av

# %%
alpha = 0.999

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names + opt_names:
    runs = running_average(losses[model_name][opt_name].T, alpha)
    plt.plot(runs.mean(axis=1))
    plt.fill_between(
        np.arange(runs.shape[0]),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + opt_names)

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names + opt_names:
    runs = running_average(losses[model_name][opt_name].T, alpha)
    time_runs = times[model_name][opt_name].T
    plt.plot(time_runs.mean(axis=1), runs.mean(axis=1))
    plt.fill_between(
        time_runs.mean(axis=1),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + opt_names)

# %%
plt.figure(figsize=(15,8))
for opt_name in meta_opt_names + opt_names:
    runs = running_average(test_losses[model_name][opt_name].T, alpha)
    plt.plot(runs.mean(axis=1))
    plt.fill_between(
        np.arange(runs.shape[0]),
        runs.mean(axis=1) - runs.std(axis=1),
        runs.mean(axis=1) + runs.std(axis=1),
        alpha=0.5
    )
plt.grid(True)
plt.ylim(0.0, 0.1)
plt.legend(meta_opt_names + opt_names)
